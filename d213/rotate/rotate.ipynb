# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def rotate(arr):
    x = arr[0]
    y = arr[1]
    return(np.array([1171 - x + y, 133 + int((x + y) / 2)]))
# [x, y] -> [odd - x + y, any int + floor((x + y) / 2)]

# %%
dlp = np.arange(1140*912).reshape(1140, 912)

# %%
plt.imshow(dlp)

# %%
dlp_i = np.zeros((2, 1140, 912))

# %%
for y in range(1140):
    for x in range(912):
        dlp_i[0, y, x] = y
        dlp_i[1, y, x] = x

# %%
dlp_i_flat = dlp_i.reshape(2, -1)

# %%
dlp_i_rotate = np.zeros(dlp_i_flat.shape)

# %%
for i in range(dlp_i_flat.shape[1]):
    dlp_i_rotate[:, i] = rotate(dlp_i_flat[:, i])

# %%
dlp_i_rotate.max(), dlp_i_rotate.min()
# Out:
# (2082.0, 32.0)

# %%
dlp_i_rotate[0, :].max(), dlp_i_rotate[0, :].min()
# Out:
# (2082.0, 32.0)

# %%
dlp_i_rotate[1, :].max(), dlp_i_rotate[1, :].min()
# Out:
# (1158.0, 133.0)

# %%
screen = np.zeros((2100, 1200))
for i in range(1140*912):
    if i == 1:
        screen[int(dlp_i_rotate[0, i]), int(dlp_i_rotate[1, i])] = 1000000
    else:
        screen[int(dlp_i_rotate[0, i]), int(dlp_i_rotate[1, i])] = i

# %%
fig = plt.figure(figsize=(11.40, 9.12))
plt.imshow(screen, aspect='auto')
